# %%
# data from https://github.com/fivethirtyeight/data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../../data/ahca-polls/ahca_polls.csv', encoding='ISO-8859-1')
df.head()
# Out:
#      Start      End               Pollster  Favor  Oppose  \
# 0   6/9/17  6/11/17  Public Policy Polling     24      55
# 1   6/4/17   6/6/17                 YouGov     33      45
# 2  5/31/17   6/6/17              Qunnipiac     17      62
# 3  5/26/17  5/30/17                 IPSOS      30      46
# 4  5/25/17  5/30/17        Morning Consult     38      47
#
#                                                  Url  \
# 0  http://www.publicpolicypolling.com/pdf/2017/PP...
# 1  https://d25d2506sfb94s.cloudfront.net/cumulus_...
# 2  https://poll.qu.edu/national/release-detail?Re...
# 3  https://www.realclearpolitics.com/docs/Core_Po...
# 4  https://morningconsult.com/wp-content/uploads/...
#
#                                                 Text
# 0  Do you support or oppose the health care bill ...
# 1  Do you approve or disapprove of the American H...
# 2  There is a revised Republican health care plan...
# 3  Based on everything you know about the new Ame...
# ...

# %%
df.describe()
# Out:
#            Favor     Oppose
# count  15.000000  15.000000
# mean   28.333333  50.666667
# std     6.343350   5.639993
# min    17.000000  44.000000
# 25%    23.500000  46.500000
# 50%    31.000000  48.000000
# 75%    31.500000  55.000000
# max    38.000000  62.000000

# %%
df['Text'].apply(lambda x:print(x))
# Out:
# Do you support or oppose the health care bill passed by the House last month, known as the American Health Care Act?
# Do you approve or disapprove of the American Health Care Act, the Republican legislation to repeal and replace the Affordable Care Act/Obamacare?
# There is a revised Republican health care plan to replace Obamacare, known as the American Health Care Act. Do you approve or disapprove of this revised Republican health care plan?
# Based on everything you know about the new American Health Care Act (AHCA), to what extent do you support or oppose it?
# As you may know, the House of Representatives recently passed a bill called the American Health Care Act that would that repeal and replace the 2010 Affordable Care Act, sometimes referred to as Obamacare. Based on what you know, do you approve or disapprove of this health care bill?
# ...
