# %%
# data from https://github.com/fivethirtyeight/data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df1 = pd.read_csv('../../data/births/US_births_1994-2003_CDC_NCHS.csv')
df2 = pd.read_csv('../../data/births/US_births_2000-2014_SSA.csv')
df = df1.append(df2, ignore_index=True)
#print(df1.head())
#print(df2.head())
del(df1, df2)
df.head()
# Out:
#    year  month  date_of_month  day_of_week  births
# 0  1994      1              1            6    8096
# 1  1994      1              2            7    7772
# 2  1994      1              3            1   10142
# 3  1994      1              4            2   11248
# 4  1994      1              5            3   11053

# %%
df.describe()
# Out:
#               year        month  date_of_month  day_of_week        births
# count  9131.000000  9131.000000    9131.000000  9131.000000   9131.000000
# mean   2003.599825     6.523053      15.729274     3.999781  11160.788632
# std       5.642836     3.448858       8.800420     2.000493   2163.504477
# min    1994.000000     1.000000       1.000000     1.000000   5728.000000
# 25%    2000.000000     4.000000       8.000000     2.000000   8787.000000
# 50%    2003.000000     7.000000      16.000000     4.000000  11998.000000
# 75%    2008.000000    10.000000      23.000000     6.000000  12774.000000
# max    2014.000000    12.000000      31.000000     7.000000  16081.000000

# %%
# how do we show a picture of total number of births by day of week
# how do I show number of births per month, or year?

df[['day_of_week', 'births']].groupby('day_of_week').sum()
#df[['day_of_week', 'births']].groupby('day_of_week').sum().hist()
#df[['day_of_week', 'births']].groupby('day_of_week').sum().plot()
# Out:
#                births
# day_of_week
# 1            15105167
# 2            16721070
# 3            16431985
# 4            16333865
# 5            16083856
# 6            11266606
# 7             9966612

# %%
df[['month', 'births']].groupby('month').sum().plot()

# %%
df.groupby('day_of_week').sum()
# Out:
#                 year  month  date_of_month    births
# day_of_week
# 1            2614697   8516          20527  15105167
# 2            2614701   8512          20492  16721070
# 3            2614705   8505          20550  16431985
# 4            2610691   8487          20513  16333865
# 5            2610693   8505          20537  16083856
# 6            2614690   8516          20475  11266606
# 7            2614693   8521          20530   9966612
